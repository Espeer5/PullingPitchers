# %%
from sklearn.cluster import KMeans
import cluster as cl
import viz
import pybaseball as pb

# %%
def pickle_kmeans(cluster_num):
    for i in range(1, cluster_num+1):
        arsenals = cl.get_ars()
        n_init='auto', n_clusters=
        cl.to_pickle(kmeans, i)i)
        kmeans.fit(arsenals)kmeans = KMeans(

# %%
pickle_kmeans(100)
viz.plot_inertias(100)

# %%
def avg_pb_stat(cl_num, stat):
    cluster = cl.get_pickle(cl_num)
    arsenals = cl.normalize(cl.collect())
    clean_empt(arsenals)
    avgs = []
    agg_stats = pb.pitching_stats(2021, 2021)
    for i in range(cl_num):
        avg = 0
        cls = get_group(arsenals, kmeans, i, cl_num)
        j = 0
        for player in cls:
            avg += arsenals[player][feature]
            j += 1
        avg = avg / j
        avgs.append(avg)
